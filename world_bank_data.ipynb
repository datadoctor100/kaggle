# %%
# Import libraries
import os
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

# Set configs
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.style.use('fivethirtyeight')

# Load data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
# Load data
os.chdir('/Users/zxs/Documents/data/exports')

exports_ = {'meta': pd.read_csv('meta.csv'),
            'data': pd.read_csv('exports.csv', skiprows = 4)}

# %%
exports_['data'].head()
# Out:
#   Country Name Country Code                               Indicator Name  \
# 0        Aruba          ABW  Arms exports (SIPRI trend indicator values)
# 1  Afghanistan          AFG  Arms exports (SIPRI trend indicator values)
# 2       Angola          AGO  Arms exports (SIPRI trend indicator values)
# 3      Albania          ALB  Arms exports (SIPRI trend indicator values)
# 4      Andorra          AND  Arms exports (SIPRI trend indicator values)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...  2011  2012  2013  \
# 0  MS.MIL.XPRT.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 1  MS.MIL.XPRT.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 2  MS.MIL.XPRT.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 3  MS.MIL.XPRT.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...   0.0   NaN   NaN
# 4  MS.MIL.XPRT.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
#
#    2014  2015  2016  2017  2018  2019  Unnamed: 64
# ...

# %%
exports_['meta'].head()
# Out:
#   Country Code                     Region          IncomeGroup SpecialNotes  \
# 0          ABW  Latin America & Caribbean          High income          NaN
# 1          AFG                 South Asia           Low income          NaN
# 2          AGO         Sub-Saharan Africa  Lower middle income          NaN
# 3          ALB      Europe & Central Asia  Upper middle income          NaN
# 4          AND      Europe & Central Asia          High income          NaN
#
#      TableName  Unnamed: 5
# 0        Aruba         NaN
# 1  Afghanistan         NaN
# 2       Angola         NaN
# 3      Albania         NaN
# 4      Andorra         NaN

# %%
# Load data
os.chdir('/Users/zxs/Documents/data/imports')

imports_ = {'meta': pd.read_csv('meta.csv'),
            'data': pd.read_csv('imports.csv', skiprows = 4)}

# %%
imports_['data'].head()
# Out:
#   Country Name Country Code                               Indicator Name  \
# 0        Aruba          ABW  Arms imports (SIPRI trend indicator values)
# 1  Afghanistan          AFG  Arms imports (SIPRI trend indicator values)
# 2       Angola          AGO  Arms imports (SIPRI trend indicator values)
# 3      Albania          ALB  Arms imports (SIPRI trend indicator values)
# 4      Andorra          AND  Arms imports (SIPRI trend indicator values)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  MS.MIL.MPRT.KD         NaN         NaN         NaN         NaN         NaN
# 1  MS.MIL.MPRT.KD  40000000.0  56000000.0  64000000.0  40000000.0  56000000.0
# 2  MS.MIL.MPRT.KD         NaN         NaN         NaN         NaN         NaN
# 3  MS.MIL.MPRT.KD  62000000.0  74000000.0  46000000.0  11000000.0   7000000.0
# 4  MS.MIL.MPRT.KD         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
# Visualize GPD data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(column = 'pop_est', figsize = [50, 20], legend = True)
plt.axis('off'),
plt.title('World Map Based On Estimated Population');

# %%
# Subset desired columns
keep = ['Country Name', 'Country Code', '2019']
expdat = exports_['data'][[i for i in keep]]
impdat = imports_['data'][[i for i in keep]].rename({'2019': 'imports'}, axis = 1)

# Select data
expdat = world.merge(expdat, left_on = 'iso_a3', right_on = 'Country Code').rename({'2019': 'exports'}, axis = 1)

data = expdat.merge(impdat[['Country Code', 'imports']], on = 'Country Code').drop(['name', 'iso_a3'], axis = 1)

# %%
print('Following Countries have no recorded exports for 2019: ')
print([i for i in data.loc[data['exports'].isna()]['Country Name'].unique()])
# Out:
# Following Countries have no recorded exports for 2019:
# ...

# %%
print('Following Countries have no recorded imports for 2019: ')
print([i for i in data.loc[data['imports'].isna()]['Country Name']])
# Out:
# Following Countries have no recorded imports for 2019:
# ['Fiji', 'Tanzania', 'Papua New Guinea', 'Congo, Dem. Rep.', 'Sudan', 'Haiti', 'Dominican Republic', 'Russian Federation', 'Bahamas, The', 'Greenland', 'Timor-Leste', 'South Africa', 'Peru', 'Panama', 'Costa Rica', 'El Salvador', 'Belize', 'Venezuela, RB', 'Suriname', 'Puerto Rico', 'Cuba', 'Zimbabwe', 'Namibia', 'Benin', 'Guinea', 'Guinea-Bissau', 'Liberia', 'Sierra Leone', 'Central African Republic', 'Congo, Rep.', 'Equatorial Guinea', 'Malawi', 'Eswatini', 'Burundi', 'Gambia, The', 'Vanuatu', 'Korea, Dem. People’s Rep.', 'Bhutan', 'Turkmenistan', 'Syrian Arab Republic', 'Moldova', 'Luxembourg', 'New Caledonia', 'Denmark', 'Iceland', 'Brunei Darussalam', 'Slovenia', 'Eritrea', 'Yemen, Rep.', 'Libya', 'Rwanda', 'Bosnia and Herzegovina', 'North Macedonia', 'Montenegro', 'Trinidad and Tobago', 'South Sudan']

# %%
# Fill missing records
data[['imports', 'exports']] = data[['imports', 'exports']].fillna(0)

# Calculate overall
data['net'] = data['exports'] - data['imports']

# %%
data.head()
# Out:
#      pop_est      continent  gdp_md_est  \
# 0     920938        Oceania      8374.0
# 1   53950935         Africa    150600.0
# 2   35623680  North America   1674000.0
# 3  326625791  North America  18560000.0
# 4   18556698           Asia    460700.0
#
#                                             geometry   Country Name  \
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...           Fiji
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...       Tanzania
# 2  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...         Canada
# 3  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...  United States
# 4  POLYGON ((87.35997 49.21498, 86.59878 48.54918...     Kazakhstan
#
#   Country Code       exports       imports           net
# 0          FJI  0.000000e+00  0.000000e+00  0.000000e+00
# 1          TZA  0.000000e+00  0.000000e+00  0.000000e+00
# 2          CAN  1.880000e+08  2.000000e+08 -1.200000e+07
# 3          USA  1.075200e+10  1.048000e+09  9.704000e+09
# ...

# %%
# Visualize GPD data
data.plot(column = 'net', figsize = [50, 20], legend = True)
plt.axis('off'),
plt.title('World Map Based On Net Export Traffic');

# %%
# Visualize GPD data
data.plot(column = 'imports', figsize = [50, 20], legend = True)
plt.axis('off'),
plt.title('World Map Based On Gross Import Traffic');
